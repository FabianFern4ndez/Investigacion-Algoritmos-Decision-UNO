# %%
# ============================================
# IMPORTS
#pip install rlcard[torch]
#pip install pandas
#pip install numpy
# ============================================
import rlcard
from rlcard.agents import RandomAgent, CFRAgent
from rlcard.utils import set_seed
import numpy as np
import pandas as pd
import time
from collections import defaultdict

# %%
class RuleBasedAgent:
    """Agente agresivo: SIEMPRE prioriza cartas de ataque (+2, +4, Skip, Reverse)"""
    
    def __init__(self, num_actions):
        self.use_raw = False
        self.num_actions = num_actions
    
    def step(self, state):
        legal_actions = list(state['legal_actions'].keys())
        
        if not legal_actions:
            return None
        
        obs = state['obs']
        hand_size = np.sum(obs[:60])
        
        # Categorizar cartas
        draw_cards = []      # +2 y +4 (MÁS DAÑINAS)
        skip_reverse = []    # Skip y Reverse
        numbers = []         # Cartas numéricas
        wilds = []          # Wild normales
        
        for action in legal_actions:
            action_str = str(action).lower()
            if 'draw' in action_str:
                draw_cards.append(action)
            elif 'skip' in action_str or 'reverse' in action_str:
                skip_reverse.append(action)
            elif 'wild' in action_str:
                wilds.append(action)
            else:
                numbers.append(action)
        
        # ESTRATEGIA AGRESIVA:
        # Si tengo 1 carta, jugar lo que sea para ganar
        if hand_size <= 1:
            if numbers:
                return np.random.choice(numbers)
            elif draw_cards:
                return np.random.choice(draw_cards)
            elif skip_reverse:
                return np.random.choice(skip_reverse)
            else:
                return np.random.choice(wilds)
        
        # En cualquier otro caso: ATACAR PRIMERO
        # Prioridad: +2/+4 > Skip/Reverse > Números > Wilds
        if draw_cards:
            return np.random.choice(draw_cards)
        elif skip_reverse:
            return np.random.choice(skip_reverse)
        elif numbers:
            return np.random.choice(numbers)
        else:
            return np.random.choice(wilds)
    
    def eval_step(self, state):
        return self.step(state), []

# %%
class ProbabilisticAgent:
    """Agente defensivo: Calcula probabilidades para jugar conservador, guarda cartas especiales"""
    
    def __init__(self, num_actions):
        self.use_raw = False
        self.num_actions = num_actions
    
    def step(self, state):
        legal_actions = list(state['legal_actions'].keys())
        
        if not legal_actions:
            return None
        
        obs = state['obs']
        hand_size = np.sum(obs[:60])
        
        # Asignar probabilidades CONSERVADORAS
        probabilities = []
        for action in legal_actions:
            action_str = str(action).lower()
            prob = 1.0
            
            # ESTRATEGIA DEFENSIVA: Priorizar números, guardar especiales
            
            # Factor 1: Cartas numéricas = ALTA PROBABILIDAD
            if not any(x in action_str for x in ['wild', 'skip', 'reverse', 'draw']):
                prob *= 5.0  # MUCHO más probable jugar números
            
            # Factor 2: Cartas especiales = BAJA PROBABILIDAD (guardar)
            if 'wild' in action_str:
                if hand_size <= 2:
                    prob *= 3.0  # Solo usar wilds al final
                else:
                    prob *= 0.1  # EVITAR wilds hasta el final
            
            if 'draw' in action_str:
                if hand_size <= 3:
                    prob *= 2.0  # Usar +2/+4 solo si estás cerca de ganar
                else:
                    prob *= 0.3  # EVITAR gastar +2/+4 temprano
            
            if 'skip' in action_str or 'reverse' in action_str:
                if hand_size <= 4:
                    prob *= 1.5
                else:
                    prob *= 0.5  # Guardar skip/reverse
            
            # Factor 3: Si tenemos MUCHAS cartas, ser más agresivo
            if hand_size > 8:
                prob *= 1.5  # Urgencia por deshacerse de cartas
            
            probabilities.append(prob)
        
        # Normalizar probabilidades
        probabilities = np.array(probabilities)
        probabilities = probabilities / probabilities.sum()
        
        return np.random.choice(legal_actions, p=probabilities)
    
    def eval_step(self, state):
        return self.step(state), []

# %%
# ============================================
# SISTEMA DE EVALUACIÓN
# ============================================
class UNOEvaluator:
    """Sistema para evaluar y comparar agentes"""
    
    def __init__(self, env):
        self.env = env
        self.metrics = defaultdict(lambda: defaultdict(list))
    
    def play_game(self, agents, agent_names):
        """Juega una partida y recolecta métricas"""
        trajectories, payoffs = self.env.run(is_training=False)
        
        # Contar turnos totales de la partida
        total_turns = sum(len(traj) for traj in trajectories)
        
        game_metrics = {
            'agent_names': agent_names,
            'payoffs': payoffs,
            'num_turns': total_turns,
            'cards_remaining': []
        }
        
        # No intentar extraer cartas restantes (causa problemas)
        # Solo usar payoffs para determinar ganadores
        for _ in range(len(payoffs)):
            game_metrics['cards_remaining'].append(0)
        
        return game_metrics
    
    def evaluate_agents(self, agents_dict, num_games=1000):
        """Evalúa múltiples agentes jugando entre sí por parejas"""
        agent_names = list(agents_dict.keys())
        all_agents = list(agents_dict.values())
        
        print(f"Evaluando {len(agent_names)} agentes...")
        print(f"Nota: UNO soporta {self.env.num_players} jugadores por partida")
        
        results = {name: {
            'wins': 0,
            'losses': 0,
            'total_games': 0,
            'move_times': [],
            'turns_per_game': [],
            'scores': []
        } for name in agent_names}
        
        # Jugar partidas con parejas de agentes
        games_per_pair = num_games // (len(agent_names) * (len(agent_names) - 1) // 2)
        print(f"Jugando {games_per_pair} partidas por cada pareja de agentes")
        
        game_count = 0
        for i in range(len(agent_names)):
            for j in range(i + 1, len(agent_names)):
                agent1_name = agent_names[i]
                agent2_name = agent_names[j]
                agent1 = all_agents[i]
                agent2 = all_agents[j]
                
                print(f"\n{agent1_name} vs {agent2_name} ({games_per_pair} partidas)...")
                
                for game_num in range(games_per_pair):
                    try:
                        # Configurar agentes para esta partida
                        self.env.set_agents([agent1, agent2])
                        
                        # Medir tiempo de ejecución
                        start_time = time.time()
                        
                        # Jugar partida
                        trajectories, payoffs = self.env.run(is_training=False)
                        
                        elapsed = time.time() - start_time
                        total_turns = sum(len(traj) for traj in trajectories)
                        avg_time_per_move = elapsed / max(total_turns, 1)
                        
                        # Registrar resultados para agente 1
                        results[agent1_name]['total_games'] += 1
                        results[agent1_name]['move_times'].append(avg_time_per_move)
                        results[agent1_name]['turns_per_game'].append(total_turns)
                        
                        if payoffs[0] > 0:
                            results[agent1_name]['wins'] += 1
                            results[agent1_name]['scores'].append(1)
                        else:
                            results[agent1_name]['losses'] += 1
                            results[agent1_name]['scores'].append(0)
                        
                        # Registrar resultados para agente 2
                        results[agent2_name]['total_games'] += 1
                        results[agent2_name]['move_times'].append(avg_time_per_move)
                        results[agent2_name]['turns_per_game'].append(total_turns)
                        
                        if payoffs[1] > 0:
                            results[agent2_name]['wins'] += 1
                            results[agent2_name]['scores'].append(1)
                        else:
                            results[agent2_name]['losses'] += 1
                            results[agent2_name]['scores'].append(0)
                        
                        game_count += 1
                        if game_count % 50 == 0:
                            print(f"  Completadas {game_count} partidas totales")
                    
                    except Exception as e:
                        print(f"  Error en partida: {str(e)[:50]}")
                        continue
        
        return results
    
    def create_summary_dataframe(self, results):
        """Crea DataFrame con resumen de métricas"""
        summary_data = []
        
        for agent_name, metrics in results.items():
            if metrics['total_games'] > 0:
                summary_data.append({
                    'Agente': agent_name,
                    'Tasa_Victoria_%': (metrics['wins'] / metrics['total_games']) * 100,
                    'Partidas_Jugadas': metrics['total_games'],
                    'Victorias': metrics['wins'],
                    'Derrotas': metrics['losses'],
                    'Tiempo_Promedio_Jugada_ms': np.mean(metrics['move_times']) * 1000 if metrics['move_times'] else 0,
                    'Turnos_Promedio_Por_Juego': np.mean(metrics['turns_per_game']) if metrics['turns_per_game'] else 0,
                    'Desv_Est_Tiempo_ms': np.std(metrics['move_times']) * 1000 if metrics['move_times'] else 0
                })
        
        df = pd.DataFrame(summary_data)
        df = df.sort_values('Tasa_Victoria_%', ascending=False)
        return df
    
    def create_detailed_dataframe(self, results):
        """Crea DataFrame detallado con todas las partidas"""
        detailed_data = []
        
        for agent_name, metrics in results.items():
            for i in range(len(metrics['scores'])):
                detailed_data.append({
                    'Agente': agent_name,
                    'Partida': i + 1,
                    'Victoria': metrics['scores'][i],
                    'Tiempo_Jugada_ms': metrics['move_times'][i] * 1000 if i < len(metrics['move_times']) else 0,
                    'Turnos_Totales': metrics['turns_per_game'][i] if i < len(metrics['turns_per_game']) else 0
                })
        
        return pd.DataFrame(detailed_data)

# %%
def main():
    set_seed(42)
    env = rlcard.make('uno')
    
    print("Inicializando agentes...")
    
    # 5 agentes: los originales + agresivo
    agents_dict = {
        'Random': RandomAgent(num_actions=env.num_actions),
        'Reglas': RuleBasedAgent(num_actions=env.num_actions),
        'Probabilistico': ProbabilisticAgent(num_actions=env.num_actions),
        'CFR': CFRAgent(env, model_path=None)
    }
    
    print(f"Total de agentes: {len(agents_dict)}")
    
    # AUMENTAR A 3000 JUEGOS para tener más datos
    evaluator = UNOEvaluator(env)
    results = evaluator.evaluate_agents(agents_dict, num_games=100000)
    
    print("\n" + "="*60)
    print("RESUMEN DE RESULTADOS")
    print("="*60)
    
    summary_df = evaluator.create_summary_dataframe(results)
    print(summary_df.to_string(index=False))
    
    detailed_df = evaluator.create_detailed_dataframe(results)
    
    summary_df.to_csv('uno_agents_summary.csv', index=False)
    detailed_df.to_csv('uno_agents_detailed.csv', index=False)
    
    print("\n✓ Archivos guardados:")
    print("  - uno_agents_summary.csv (resumen por agente)")
    print("  - uno_agents_detailed.csv (datos de cada partida)")
    
    print("\n" + "="*60)
    print("ANÁLISIS COMPARATIVO")
    print("="*60)
    
    for agent_name in agents_dict.keys():
        metrics = results[agent_name]
        win_rate = (metrics['wins']/metrics['total_games']*100)
        print(f"\n{agent_name}:")
        print(f"  Victorias: {metrics['wins']}/{metrics['total_games']}")
        print(f"  Tasa victoria: {win_rate:.2f}%")
        print(f"  Tiempo: {np.mean(metrics['move_times'])*1000:.3f} ms")


if __name__ == "__main__":
    main()
# Out:
# Inicializando agentes...
# Total de agentes: 4
# Evaluando 4 agentes...
# Nota: UNO soporta 2 jugadores por partida
# Jugando 16666 partidas por cada pareja de agentes
#
# Random vs Reglas (16666 partidas)...
#   Completadas 50 partidas totales
#   Completadas 100 partidas totales
#   Completadas 150 partidas totales
#   Completadas 200 partidas totales
#   Completadas 250 partidas totales
#   Completadas 300 partidas totales
#   Completadas 350 partidas totales
#   Completadas 400 partidas totales
#   Completadas 450 partidas totales
#   Completadas 500 partidas totales
#   Completadas 550 partidas totales
#   Completadas 600 partidas totales
#   Completadas 650 partidas totales
#   Completadas 700 partidas totales
#   Completadas 750 partidas totales
#   Completadas 800 partidas totales
#   Completadas 850 partidas totales
#   Completadas 900 partidas totales
#   Completadas 950 partidas totales
#   Completadas 1000 partidas totales
#   Completadas 1050 partidas totales
#   Completadas 1100 partidas totales
#   Completadas 1150 partidas totales
#   Completadas 1200 partidas totales
#   Completadas 1250 partidas totales
#   Completadas 1300 partidas totales
#   Completadas 1350 partidas totales
#   Completadas 1400 partidas totales
#   Completadas 1450 partidas totales
#   Completadas 1500 partidas totales
#   Completadas 1550 partidas totales
#   Completadas 1600 partidas totales
#   Completadas 1650 partidas totales
#   Completadas 1700 partidas totales
#   Completadas 1750 partidas totales
#   Completadas 1800 partidas totales
#   Completadas 1850 partidas totales
#   Completadas 1900 partidas totales
#   Completadas 1950 partidas totales
#   Completadas 2000 partidas totales
#   Completadas 2050 partidas totales
#   Completadas 2100 partidas totales
#   Completadas 2150 partidas totales
#   Completadas 2200 partidas totales
#   Completadas 2250 partidas totales
#   Completadas 2300 partidas totales
#   Completadas 2350 partidas totales
#   Completadas 2400 partidas totales
#   Completadas 2450 partidas totales
#   Completadas 2500 partidas totales
#   Completadas 2550 partidas totales
#   Completadas 2600 partidas totales
#   Completadas 2650 partidas totales
#   Completadas 2700 partidas totales
#   Completadas 2750 partidas totales
#   Completadas 2800 partidas totales
#   Completadas 2850 partidas totales
#   Completadas 2900 partidas totales
#   Completadas 2950 partidas totales
#   Completadas 3000 partidas totales
#   Completadas 3050 partidas totales
#   Completadas 3100 partidas totales
#   Completadas 3150 partidas totales
#   Completadas 3200 partidas totales
#   Completadas 3250 partidas totales
#   Completadas 3300 partidas totales
#   Completadas 3350 partidas totales
#   Completadas 3400 partidas totales
#   Completadas 3450 partidas totales
#   Completadas 3500 partidas totales
#   Completadas 3550 partidas totales
#   Completadas 3600 partidas totales
#   Completadas 3650 partidas totales
#   Completadas 3700 partidas totales
#   Completadas 3750 partidas totales
#   Completadas 3800 partidas totales
#   Completadas 3850 partidas totales
#   Completadas 3900 partidas totales
#   Completadas 3950 partidas totales
#   Completadas 4000 partidas totales
#   Completadas 4050 partidas totales
#   Completadas 4100 partidas totales
#   Completadas 4150 partidas totales
#   Completadas 4200 partidas totales
#   Completadas 4250 partidas totales
#   Completadas 4300 partidas totales
#   Completadas 4350 partidas totales
#   Completadas 4400 partidas totales
#   Completadas 4450 partidas totales
#   Completadas 4500 partidas totales
#   Completadas 4550 partidas totales
#   Completadas 4600 partidas totales
#   Completadas 4650 partidas totales
#   Completadas 4700 partidas totales
#   Completadas 4750 partidas totales
#   Completadas 4800 partidas totales
#   Completadas 4850 partidas totales
#   Completadas 4900 partidas totales
#   Completadas 4950 partidas totales
#   Completadas 5000 partidas totales
#   Completadas 5050 partidas totales
#   Completadas 5100 partidas totales
#   Completadas 5150 partidas totales
#   Completadas 5200 partidas totales
#   Completadas 5250 partidas totales
#   Completadas 5300 partidas totales
#   Completadas 5350 partidas totales
#   Completadas 5400 partidas totales
#   Completadas 5450 partidas totales
#   Completadas 5500 partidas totales
#   Completadas 5550 partidas totales
#   Completadas 5600 partidas totales
#   Completadas 5650 partidas totales
#   Completadas 5700 partidas totales
#   Completadas 5750 partidas totales
#   Completadas 5800 partidas totales
#   Completadas 5850 partidas totales
#   Completadas 5900 partidas totales
#   Completadas 5950 partidas totales
#   Completadas 6000 partidas totales
#   Completadas 6050 partidas totales
#   Completadas 6100 partidas totales
#   Completadas 6150 partidas totales
#   Completadas 6200 partidas totales
#   Completadas 6250 partidas totales
#   Completadas 6300 partidas totales
#   Completadas 6350 partidas totales
#   Completadas 6400 partidas totales
#   Completadas 6450 partidas totales
#   Completadas 6500 partidas totales
#   Completadas 6550 partidas totales
#   Completadas 6600 partidas totales
#   Completadas 6650 partidas totales
#   Completadas 6700 partidas totales
#   Completadas 6750 partidas totales
#   Completadas 6800 partidas totales
#   Completadas 6850 partidas totales
#   Completadas 6900 partidas totales
#   Completadas 6950 partidas totales
#   Completadas 7000 partidas totales
#   Completadas 7050 partidas totales
#   Completadas 7100 partidas totales
#   Completadas 7150 partidas totales
#   Completadas 7200 partidas totales
#   Completadas 7250 partidas totales
#   Completadas 7300 partidas totales
#   Completadas 7350 partidas totales
#   Completadas 7400 partidas totales
#   Completadas 7450 partidas totales
#   Completadas 7500 partidas totales
#   Completadas 7550 partidas totales
#   Completadas 7600 partidas totales
#   Completadas 7650 partidas totales
#   Completadas 7700 partidas totales
#   Completadas 7750 partidas totales
#   Completadas 7800 partidas totales
#   Completadas 7850 partidas totales
#   Completadas 7900 partidas totales
#   Completadas 7950 partidas totales
#   Completadas 8000 partidas totales
#   Completadas 8050 partidas totales
#   Completadas 8100 partidas totales
#   Completadas 8150 partidas totales
#   Completadas 8200 partidas totales
#   Completadas 8250 partidas totales
#   Completadas 8300 partidas totales
#   Completadas 8350 partidas totales
#   Completadas 8400 partidas totales
#   Completadas 8450 partidas totales
#   Completadas 8500 partidas totales
#   Completadas 8550 partidas totales
#   Completadas 8600 partidas totales
#   Completadas 8650 partidas totales
#   Completadas 8700 partidas totales
#   Completadas 8750 partidas totales
#   Completadas 8800 partidas totales
#   Completadas 8850 partidas totales
#   Completadas 8900 partidas totales
#   Completadas 8950 partidas totales
#   Completadas 9000 partidas totales
#   Completadas 9050 partidas totales
#   Completadas 9100 partidas totales
#   Completadas 9150 partidas totales
#   Completadas 9200 partidas totales
#   Completadas 9250 partidas totales
#   Completadas 9300 partidas totales
#   Completadas 9350 partidas totales
#   Completadas 9400 partidas totales
#   Completadas 9450 partidas totales
#   Completadas 9500 partidas totales
#   Completadas 9550 partidas totales
#   Completadas 9600 partidas totales
#   Completadas 9650 partidas totales
#   Completadas 9700 partidas totales
#   Completadas 9750 partidas totales
#   Completadas 9800 partidas totales
#   Completadas 9850 partidas totales
#   Completadas 9900 partidas totales
#   Completadas 9950 partidas totales
#   Completadas 10000 partidas totales
#   Completadas 10050 partidas totales
#   Completadas 10100 partidas totales
#   Completadas 10150 partidas totales
#   Completadas 10200 partidas totales
#   Completadas 10250 partidas totales
#   Completadas 10300 partidas totales
#   Completadas 10350 partidas totales
#   Completadas 10400 partidas totales
#   Completadas 10450 partidas totales
#   Completadas 10500 partidas totales
#   Completadas 10550 partidas totales
#   Completadas 10600 partidas totales
#   Completadas 10650 partidas totales
#   Completadas 10700 partidas totales
#   Completadas 10750 partidas totales
#   Completadas 10800 partidas totales
#   Completadas 10850 partidas totales
#   Completadas 10900 partidas totales
#   Completadas 10950 partidas totales
#   Completadas 11000 partidas totales
#   Completadas 11050 partidas totales
#   Completadas 11100 partidas totales
#   Completadas 11150 partidas totales
#   Completadas 11200 partidas totales
#   Completadas 11250 partidas totales
#   Completadas 11300 partidas totales
#   Completadas 11350 partidas totales
#   Completadas 11400 partidas totales
#   Completadas 11450 partidas totales
#   Completadas 11500 partidas totales
#   Completadas 11550 partidas totales
#   Completadas 11600 partidas totales
#   Completadas 11650 partidas totales
#   Completadas 11700 partidas totales
#   Completadas 11750 partidas totales
#   Completadas 11800 partidas totales
#   Completadas 11850 partidas totales
#   Completadas 11900 partidas totales
#   Completadas 11950 partidas totales
#   Completadas 12000 partidas totales
#   Completadas 12050 partidas totales
#   Completadas 12100 partidas totales
#   Completadas 12150 partidas totales
#   Completadas 12200 partidas totales
#   Completadas 12250 partidas totales
#   Completadas 12300 partidas totales
#   Completadas 12350 partidas totales
#   Completadas 12400 partidas totales
#   Completadas 12450 partidas totales
#   Completadas 12500 partidas totales
#   Completadas 12550 partidas totales
#   Completadas 12600 partidas totales
#   Completadas 12650 partidas totales
#   Completadas 12700 partidas totales
#   Completadas 12750 partidas totales
#   Completadas 12800 partidas totales
#   Completadas 12850 partidas totales
#   Completadas 12900 partidas totales
#   Completadas 12950 partidas totales
#   Completadas 13000 partidas totales
#   Completadas 13050 partidas totales
#   Completadas 13100 partidas totales
#   Completadas 13150 partidas totales
#   Completadas 13200 partidas totales
#   Completadas 13250 partidas totales
#   Completadas 13300 partidas totales
#   Completadas 13350 partidas totales
#   Completadas 13400 partidas totales
#   Completadas 13450 partidas totales
#   Completadas 13500 partidas totales
#   Completadas 13550 partidas totales
#   Completadas 13600 partidas totales
#   Completadas 13650 partidas totales
#   Completadas 13700 partidas totales
#   Completadas 13750 partidas totales
#   Completadas 13800 partidas totales
#   Completadas 13850 partidas totales
#   Completadas 13900 partidas totales
#   Completadas 13950 partidas totales
#   Completadas 14000 partidas totales
#   Completadas 14050 partidas totales
#   Completadas 14100 partidas totales
#   Completadas 14150 partidas totales
#   Completadas 14200 partidas totales
#   Completadas 14250 partidas totales
#   Completadas 14300 partidas totales
#   Completadas 14350 partidas totales
#   Completadas 14400 partidas totales
#   Completadas 14450 partidas totales
#   Completadas 14500 partidas totales
#   Completadas 14550 partidas totales
#   Completadas 14600 partidas totales
#   Completadas 14650 partidas totales
#   Completadas 14700 partidas totales
#   Completadas 14750 partidas totales
#   Completadas 14800 partidas totales
#   Completadas 14850 partidas totales
#   Completadas 14900 partidas totales
#   Completadas 14950 partidas totales
#   Completadas 15000 partidas totales
#   Completadas 15050 partidas totales
#   Completadas 15100 partidas totales
#   Completadas 15150 partidas totales
#   Completadas 15200 partidas totales
#   Completadas 15250 partidas totales
#   Completadas 15300 partidas totales
#   Completadas 15350 partidas totales
#   Completadas 15400 partidas totales
#   Completadas 15450 partidas totales
#   Completadas 15500 partidas totales
#   Completadas 15550 partidas totales
#   Completadas 15600 partidas totales
#   Completadas 15650 partidas totales
#   Completadas 15700 partidas totales
#   Completadas 15750 partidas totales
#   Completadas 15800 partidas totales
#   Completadas 15850 partidas totales
#   Completadas 15900 partidas totales
#   Completadas 15950 partidas totales
#   Completadas 16000 partidas totales
#   Completadas 16050 partidas totales
#   Completadas 16100 partidas totales
#   Completadas 16150 partidas totales
#   Completadas 16200 partidas totales
#   Completadas 16250 partidas totales
#   Completadas 16300 partidas totales
#   Completadas 16350 partidas totales
#   Completadas 16400 partidas totales
#   Completadas 16450 partidas totales
#   Completadas 16500 partidas totales
#   Completadas 16550 partidas totales
#   Completadas 16600 partidas totales
#   Completadas 16650 partidas totales
#
# Random vs Probabilistico (16666 partidas)...
#   Completadas 16700 partidas totales
#   Completadas 16750 partidas totales
#   Completadas 16800 partidas totales
#   Completadas 16850 partidas totales
#   Completadas 16900 partidas totales
#   Completadas 16950 partidas totales
#   Completadas 17000 partidas totales
#   Completadas 17050 partidas totales
#   Completadas 17100 partidas totales
#   Completadas 17150 partidas totales
#   Completadas 17200 partidas totales
#   Completadas 17250 partidas totales
#   Completadas 17300 partidas totales
#   Completadas 17350 partidas totales
#   Completadas 17400 partidas totales
#   Completadas 17450 partidas totales
#   Completadas 17500 partidas totales
#   Completadas 17550 partidas totales
#   Completadas 17600 partidas totales
#   Completadas 17650 partidas totales
#   Completadas 17700 partidas totales
#   Completadas 17750 partidas totales
#   Completadas 17800 partidas totales
#   Completadas 17850 partidas totales
#   Completadas 17900 partidas totales
#   Completadas 17950 partidas totales
#   Completadas 18000 partidas totales
#   Completadas 18050 partidas totales
#   Completadas 18100 partidas totales
#   Completadas 18150 partidas totales
#   Completadas 18200 partidas totales
#   Completadas 18250 partidas totales
#   Completadas 18300 partidas totales
#   Completadas 18350 partidas totales
#   Completadas 18400 partidas totales
#   Completadas 18450 partidas totales
#   Completadas 18500 partidas totales
#   Completadas 18550 partidas totales
#   Completadas 18600 partidas totales
#   Completadas 18650 partidas totales
#   Completadas 18700 partidas totales
#   Completadas 18750 partidas totales
#   Completadas 18800 partidas totales
#   Completadas 18850 partidas totales
#   Completadas 18900 partidas totales
#   Completadas 18950 partidas totales
#   Completadas 19000 partidas totales
#   Completadas 19050 partidas totales
#   Completadas 19100 partidas totales
#   Completadas 19150 partidas totales
#   Completadas 19200 partidas totales
#   Completadas 19250 partidas totales
#   Completadas 19300 partidas totales
#   Completadas 19350 partidas totales
#   Completadas 19400 partidas totales
#   Completadas 19450 partidas totales
#   Completadas 19500 partidas totales
#   Completadas 19550 partidas totales
#   Completadas 19600 partidas totales
#   Completadas 19650 partidas totales
#   Completadas 19700 partidas totales
#   Completadas 19750 partidas totales
#   Completadas 19800 partidas totales
#   Completadas 19850 partidas totales
#   Completadas 19900 partidas totales
#   Completadas 19950 partidas totales
#   Completadas 20000 partidas totales
#   Completadas 20050 partidas totales
#   Completadas 20100 partidas totales
#   Completadas 20150 partidas totales
#   Completadas 20200 partidas totales
#   Completadas 20250 partidas totales
#   Completadas 20300 partidas totales
#   Completadas 20350 partidas totales
#   Completadas 20400 partidas totales
#   Completadas 20450 partidas totales
#   Completadas 20500 partidas totales
#   Completadas 20550 partidas totales
#   Completadas 20600 partidas totales
#   Completadas 20650 partidas totales
#   Completadas 20700 partidas totales
#   Completadas 20750 partidas totales
#   Completadas 20800 partidas totales
#   Completadas 20850 partidas totales
#   Completadas 20900 partidas totales
#   Completadas 20950 partidas totales
#   Completadas 21000 partidas totales
#   Completadas 21050 partidas totales
#   Completadas 21100 partidas totales
#   Completadas 21150 partidas totales
#   Completadas 21200 partidas totales
#   Completadas 21250 partidas totales
#   Completadas 21300 partidas totales
#   Completadas 21350 partidas totales
#   Completadas 21400 partidas totales
#   Completadas 21450 partidas totales
#   Completadas 21500 partidas totales
#   Completadas 21550 partidas totales
#   Completadas 21600 partidas totales
#   Completadas 21650 partidas totales
#   Completadas 21700 partidas totales
#   Completadas 21750 partidas totales
#   Completadas 21800 partidas totales
#   Completadas 21850 partidas totales
#   Completadas 21900 partidas totales
#   Completadas 21950 partidas totales
#   Completadas 22000 partidas totales
#   Completadas 22050 partidas totales
#   Completadas 22100 partidas totales
#   Completadas 22150 partidas totales
#   Completadas 22200 partidas totales
#   Completadas 22250 partidas totales
#   Completadas 22300 partidas totales
#   Completadas 22350 partidas totales
#   Completadas 22400 partidas totales
#   Completadas 22450 partidas totales
#   Completadas 22500 partidas totales
#   Completadas 22550 partidas totales
#   Completadas 22600 partidas totales
#   Completadas 22650 partidas totales
#   Completadas 22700 partidas totales
#   Completadas 22750 partidas totales
#   Completadas 22800 partidas totales
#   Completadas 22850 partidas totales
#   Completadas 22900 partidas totales
#   Completadas 22950 partidas totales
#   Completadas 23000 partidas totales
#   Completadas 23050 partidas totales
#   Completadas 23100 partidas totales
#   Completadas 23150 partidas totales
#   Completadas 23200 partidas totales
#   Completadas 23250 partidas totales
#   Completadas 23300 partidas totales
#   Completadas 23350 partidas totales
#   Completadas 23400 partidas totales
#   Completadas 23450 partidas totales
#   Completadas 23500 partidas totales
#   Completadas 23550 partidas totales
#   Completadas 23600 partidas totales
#   Completadas 23650 partidas totales
#   Completadas 23700 partidas totales
#   Completadas 23750 partidas totales
#   Completadas 23800 partidas totales
#   Completadas 23850 partidas totales
#   Completadas 23900 partidas totales
#   Completadas 23950 partidas totales
#   Completadas 24000 partidas totales
#   Completadas 24050 partidas totales
#   Completadas 24100 partidas totales
#   Completadas 24150 partidas totales
#   Completadas 24200 partidas totales
#   Completadas 24250 partidas totales
#   Completadas 24300 partidas totales
#   Completadas 24350 partidas totales
#   Completadas 24400 partidas totales
#   Completadas 24450 partidas totales
#   Completadas 24500 partidas totales
#   Completadas 24550 partidas totales
#   Completadas 24600 partidas totales
#   Completadas 24650 partidas totales
#   Completadas 24700 partidas totales
#   Completadas 24750 partidas totales
#   Completadas 24800 partidas totales
#   Completadas 24850 partidas totales
#   Completadas 24900 partidas totales
#   Completadas 24950 partidas totales
#   Completadas 25000 partidas totales
#   Completadas 25050 partidas totales
#   Completadas 25100 partidas totales
#   Completadas 25150 partidas totales
#   Completadas 25200 partidas totales
#   Completadas 25250 partidas totales
#   Completadas 25300 partidas totales
#   Completadas 25350 partidas totales
#   Completadas 25400 partidas totales
#   Completadas 25450 partidas totales
#   Completadas 25500 partidas totales
#   Completadas 25550 partidas totales
#   Completadas 25600 partidas totales
#   Completadas 25650 partidas totales
#   Completadas 25700 partidas totales
#   Completadas 25750 partidas totales
#   Completadas 25800 partidas totales
#   Completadas 25850 partidas totales
#   Completadas 25900 partidas totales
#   Completadas 25950 partidas totales
#   Completadas 26000 partidas totales
#   Completadas 26050 partidas totales
#   Completadas 26100 partidas totales
#   Completadas 26150 partidas totales
#   Completadas 26200 partidas totales
#   Completadas 26250 partidas totales
#   Completadas 26300 partidas totales
#   Completadas 26350 partidas totales
#   Completadas 26400 partidas totales
#   Completadas 26450 partidas totales
#   Completadas 26500 partidas totales
#   Completadas 26550 partidas totales
#   Completadas 26600 partidas totales
#   Completadas 26650 partidas totales
#   Completadas 26700 partidas totales
#   Completadas 26750 partidas totales
#   Completadas 26800 partidas totales
#   Completadas 26850 partidas totales
#   Completadas 26900 partidas totales
#   Completadas 26950 partidas totales
#   Completadas 27000 partidas totales
#   Completadas 27050 partidas totales
#   Completadas 27100 partidas totales
#   Completadas 27150 partidas totales
#   Completadas 27200 partidas totales
#   Completadas 27250 partidas totales
#   Completadas 27300 partidas totales
#   Completadas 27350 partidas totales
#   Completadas 27400 partidas totales
#   Completadas 27450 partidas totales
#   Completadas 27500 partidas totales
#   Completadas 27550 partidas totales
#   Completadas 27600 partidas totales
#   Completadas 27650 partidas totales
#   Completadas 27700 partidas totales
#   Completadas 27750 partidas totales
#   Completadas 27800 partidas totales
#   Completadas 27850 partidas totales
#   Completadas 27900 partidas totales
#   Completadas 27950 partidas totales
#   Completadas 28000 partidas totales
#   Completadas 28050 partidas totales
#   Completadas 28100 partidas totales
#   Completadas 28150 partidas totales
#   Completadas 28200 partidas totales
#   Completadas 28250 partidas totales
#   Completadas 28300 partidas totales
#   Completadas 28350 partidas totales
#   Completadas 28400 partidas totales
#   Completadas 28450 partidas totales
#   Completadas 28500 partidas totales
#   Completadas 28550 partidas totales
#   Completadas 28600 partidas totales
#   Completadas 28650 partidas totales
#   Completadas 28700 partidas totales
#   Completadas 28750 partidas totales
#   Completadas 28800 partidas totales
#   Completadas 28850 partidas totales
#   Completadas 28900 partidas totales
#   Completadas 28950 partidas totales
#   Completadas 29000 partidas totales
#   Completadas 29050 partidas totales
#   Completadas 29100 partidas totales
#   Completadas 29150 partidas totales
#   Completadas 29200 partidas totales
#   Completadas 29250 partidas totales
#   Completadas 29300 partidas totales
#   Completadas 29350 partidas totales
#   Completadas 29400 partidas totales
#   Completadas 29450 partidas totales
#   Completadas 29500 partidas totales
#   Completadas 29550 partidas totales
#   Completadas 29600 partidas totales
#   Completadas 29650 partidas totales
#   Completadas 29700 partidas totales
#   Completadas 29750 partidas totales
#   Completadas 29800 partidas totales
#   Completadas 29850 partidas totales
#   Completadas 29900 partidas totales
#   Completadas 29950 partidas totales
#   Completadas 30000 partidas totales
#   Completadas 30050 partidas totales
#   Completadas 30100 partidas totales
#   Completadas 30150 partidas totales
#   Completadas 30200 partidas totales
#   Completadas 30250 partidas totales
#   Completadas 30300 partidas totales
#   Completadas 30350 partidas totales
#   Completadas 30400 partidas totales
#   Completadas 30450 partidas totales
#   Completadas 30500 partidas totales
#   Completadas 30550 partidas totales
#   Completadas 30600 partidas totales
#   Completadas 30650 partidas totales
#   Completadas 30700 partidas totales
#   Completadas 30750 partidas totales
#   Completadas 30800 partidas totales
#   Completadas 30850 partidas totales
#   Completadas 30900 partidas totales
#   Completadas 30950 partidas totales
#   Completadas 31000 partidas totales
#   Completadas 31050 partidas totales
#   Completadas 31100 partidas totales
#   Completadas 31150 partidas totales
#   Completadas 31200 partidas totales
#   Completadas 31250 partidas totales
#   Completadas 31300 partidas totales
#   Completadas 31350 partidas totales
#   Completadas 31400 partidas totales
#   Completadas 31450 partidas totales
#   Completadas 31500 partidas totales
#   Completadas 31550 partidas totales
#   Completadas 31600 partidas totales
#   Completadas 31650 partidas totales
#   Completadas 31700 partidas totales
#   Completadas 31750 partidas totales
#   Completadas 31800 partidas totales
#   Completadas 31850 partidas totales
#   Completadas 31900 partidas totales
#   Completadas 31950 partidas totales
#   Completadas 32000 partidas totales
#   Completadas 32050 partidas totales
#   Completadas 32100 partidas totales
#   Completadas 32150 partidas totales
#   Completadas 32200 partidas totales
#   Completadas 32250 partidas totales
#   Completadas 32300 partidas totales
#   Completadas 32350 partidas totales
#   Completadas 32400 partidas totales
#   Completadas 32450 partidas totales
#   Completadas 32500 partidas totales
#   Completadas 32550 partidas totales
#   Completadas 32600 partidas totales
#   Completadas 32650 partidas totales
#   Completadas 32700 partidas totales
#   Completadas 32750 partidas totales
#   Completadas 32800 partidas totales
#   Completadas 32850 partidas totales
#   Completadas 32900 partidas totales
#   Completadas 32950 partidas totales
#   Completadas 33000 partidas totales
#   Completadas 33050 partidas totales
#   Completadas 33100 partidas totales
#   Completadas 33150 partidas totales
#   Completadas 33200 partidas totales
#   Completadas 33250 partidas totales
#   Completadas 33300 partidas totales
#
# Random vs CFR (16666 partidas)...
#   Completadas 33350 partidas totales
#   Completadas 33400 partidas totales
#   Completadas 33450 partidas totales
#   Completadas 33500 partidas totales
#   Completadas 33550 partidas totales
#   Completadas 33600 partidas totales
#   Completadas 33650 partidas totales
#   Completadas 33700 partidas totales
#   Completadas 33750 partidas totales
#   Completadas 33800 partidas totales
#   Completadas 33850 partidas totales
#   Completadas 33900 partidas totales
#   Completadas 33950 partidas totales
#   Completadas 34000 partidas totales
#   Completadas 34050 partidas totales
#   Completadas 34100 partidas totales
#   Completadas 34150 partidas totales
#   Completadas 34200 partidas totales
#   Completadas 34250 partidas totales
#   Completadas 34300 partidas totales
#   Completadas 34350 partidas totales
#   Completadas 34400 partidas totales
#   Completadas 34450 partidas totales
#   Completadas 34500 partidas totales
#   Completadas 34550 partidas totales
#   Completadas 34600 partidas totales
#   Completadas 34650 partidas totales
#   Completadas 34700 partidas totales
#   Completadas 34750 partidas totales
#   Completadas 34800 partidas totales
#   Completadas 34850 partidas totales
#   Completadas 34900 partidas totales
#   Completadas 34950 partidas totales
#   Completadas 35000 partidas totales
#   Completadas 35050 partidas totales
#   Completadas 35100 partidas totales
#   Completadas 35150 partidas totales
#   Completadas 35200 partidas totales
#   Completadas 35250 partidas totales
#   Completadas 35300 partidas totales
#   Completadas 35350 partidas totales
#   Completadas 35400 partidas totales
#   Completadas 35450 partidas totales
#   Completadas 35500 partidas totales
#   Completadas 35550 partidas totales
#   Completadas 35600 partidas totales
#   Completadas 35650 partidas totales
#   Completadas 35700 partidas totales
#   Completadas 35750 partidas totales
#   Completadas 35800 partidas totales
#   Completadas 35850 partidas totales
#   Completadas 35900 partidas totales
#   Completadas 35950 partidas totales
#   Completadas 36000 partidas totales
#   Completadas 36050 partidas totales
#   Completadas 36100 partidas totales
#   Completadas 36150 partidas totales
#   Completadas 36200 partidas totales
#   Completadas 36250 partidas totales
#   Completadas 36300 partidas totales
#   Completadas 36350 partidas totales
#   Completadas 36400 partidas totales
#   Completadas 36450 partidas totales
#   Completadas 36500 partidas totales
#   Completadas 36550 partidas totales
#   Completadas 36600 partidas totales
#   Completadas 36650 partidas totales
#   Completadas 36700 partidas totales
#   Completadas 36750 partidas totales
#   Completadas 36800 partidas totales
#   Completadas 36850 partidas totales
#   Completadas 36900 partidas totales
#   Completadas 36950 partidas totales
#   Completadas 37000 partidas totales
#   Completadas 37050 partidas totales
#   Completadas 37100 partidas totales
#   Completadas 37150 partidas totales
#   Completadas 37200 partidas totales
#   Completadas 37250 partidas totales
#   Completadas 37300 partidas totales
#   Completadas 37350 partidas totales
#   Completadas 37400 partidas totales
#   Completadas 37450 partidas totales
#   Completadas 37500 partidas totales
#   Completadas 37550 partidas totales
#   Completadas 37600 partidas totales
#   Completadas 37650 partidas totales
#   Completadas 37700 partidas totales
#   Completadas 37750 partidas totales
#   Completadas 37800 partidas totales
#   Completadas 37850 partidas totales
#   Completadas 37900 partidas totales
#   Completadas 37950 partidas totales
#   Completadas 38000 partidas totales
#   Completadas 38050 partidas totales
#   Completadas 38100 partidas totales
#   Completadas 38150 partidas totales
#   Completadas 38200 partidas totales
#   Completadas 38250 partidas totales
#   Completadas 38300 partidas totales
#   Completadas 38350 partidas totales
#   Completadas 38400 partidas totales
#   Completadas 38450 partidas totales
#   Completadas 38500 partidas totales
#   Completadas 38550 partidas totales
#   Completadas 38600 partidas totales
#   Completadas 38650 partidas totales
#   Completadas 38700 partidas totales
#   Completadas 38750 partidas totales
#   Completadas 38800 partidas totales
#   Completadas 38850 partidas totales
#   Completadas 38900 partidas totales
#   Completadas 38950 partidas totales
#   Completadas 39000 partidas totales
#   Completadas 39050 partidas totales
#   Completadas 39100 partidas totales
#   Completadas 39150 partidas totales
#   Completadas 39200 partidas totales
#   Completadas 39250 partidas totales
#   Completadas 39300 partidas totales
#   Completadas 39350 partidas totales
#   Completadas 39400 partidas totales
#   Completadas 39450 partidas totales
#   Completadas 39500 partidas totales
#   Completadas 39550 partidas totales
#   Completadas 39600 partidas totales
#   Completadas 39650 partidas totales
#   Completadas 39700 partidas totales
#   Completadas 39750 partidas totales
#   Completadas 39800 partidas totales
#   Completadas 39850 partidas totales
#   Completadas 39900 partidas totales
#   Completadas 39950 partidas totales
#   Completadas 40000 partidas totales
#   Completadas 40050 partidas totales
#   Completadas 40100 partidas totales
#   Completadas 40150 partidas totales
#   Completadas 40200 partidas totales
#   Completadas 40250 partidas totales
#   Completadas 40300 partidas totales
#   Completadas 40350 partidas totales
#   Completadas 40400 partidas totales
#   Completadas 40450 partidas totales
#   Completadas 40500 partidas totales
#   Completadas 40550 partidas totales
#   Completadas 40600 partidas totales
#   Completadas 40650 partidas totales
#   Completadas 40700 partidas totales
#   Completadas 40750 partidas totales
#   Completadas 40800 partidas totales
#   Completadas 40850 partidas totales
#   Completadas 40900 partidas totales
#   Completadas 40950 partidas totales
#   Completadas 41000 partidas totales
#   Completadas 41050 partidas totales
#   Completadas 41100 partidas totales
#   Completadas 41150 partidas totales
#   Completadas 41200 partidas totales
#   Completadas 41250 partidas totales
#   Completadas 41300 partidas totales
#   Completadas 41350 partidas totales
#   Completadas 41400 partidas totales
#   Completadas 41450 partidas totales
#   Completadas 41500 partidas totales
#   Completadas 41550 partidas totales
#   Completadas 41600 partidas totales
#   Completadas 41650 partidas totales
#   Completadas 41700 partidas totales
#   Completadas 41750 partidas totales
#   Completadas 41800 partidas totales
#   Completadas 41850 partidas totales
#   Completadas 41900 partidas totales
#   Completadas 41950 partidas totales
#   Completadas 42000 partidas totales
#   Completadas 42050 partidas totales
#   Completadas 42100 partidas totales
#   Completadas 42150 partidas totales
#   Completadas 42200 partidas totales
#   Completadas 42250 partidas totales
#   Completadas 42300 partidas totales
#   Completadas 42350 partidas totales
#   Completadas 42400 partidas totales
#   Completadas 42450 partidas totales
#   Completadas 42500 partidas totales
#   Completadas 42550 partidas totales
#   Completadas 42600 partidas totales
#   Completadas 42650 partidas totales
#   Completadas 42700 partidas totales
#   Completadas 42750 partidas totales
#   Completadas 42800 partidas totales
#   Completadas 42850 partidas totales
#   Completadas 42900 partidas totales
#   Completadas 42950 partidas totales
#   Completadas 43000 partidas totales
#   Completadas 43050 partidas totales
#   Completadas 43100 partidas totales
#   Completadas 43150 partidas totales
#   Completadas 43200 partidas totales
#   Completadas 43250 partidas totales
#   Completadas 43300 partidas totales
#   Completadas 43350 partidas totales
#   Completadas 43400 partidas totales
#   Completadas 43450 partidas totales
#   Completadas 43500 partidas totales
#   Completadas 43550 partidas totales
#   Completadas 43600 partidas totales
#   Completadas 43650 partidas totales
#   Completadas 43700 partidas totales
#   Completadas 43750 partidas totales
#   Completadas 43800 partidas totales
#   Completadas 43850 partidas totales
#   Completadas 43900 partidas totales
#   Completadas 43950 partidas totales
#   Completadas 44000 partidas totales
#   Completadas 44050 partidas totales
#   Completadas 44100 partidas totales
#   Completadas 44150 partidas totales
#   Completadas 44200 partidas totales
#   Completadas 44250 partidas totales
#   Completadas 44300 partidas totales
#   Completadas 44350 partidas totales
#   Completadas 44400 partidas totales
#   Completadas 44450 partidas totales
#   Completadas 44500 partidas totales
#   Completadas 44550 partidas totales
#   Completadas 44600 partidas totales
#   Completadas 44650 partidas totales
#   Completadas 44700 partidas totales
#   Completadas 44750 partidas totales
#   Completadas 44800 partidas totales
#   Completadas 44850 partidas totales
#   Completadas 44900 partidas totales
#   Completadas 44950 partidas totales
#   Completadas 45000 partidas totales
#   Completadas 45050 partidas totales
#   Completadas 45100 partidas totales
#   Completadas 45150 partidas totales
#   Completadas 45200 partidas totales
#   Completadas 45250 partidas totales
#   Completadas 45300 partidas totales
#   Completadas 45350 partidas totales
#   Completadas 45400 partidas totales
#   Completadas 45450 partidas totales
#   Completadas 45500 partidas totales
#   Completadas 45550 partidas totales
#   Completadas 45600 partidas totales
#   Completadas 45650 partidas totales
#   Completadas 45700 partidas totales
#   Completadas 45750 partidas totales
#   Completadas 45800 partidas totales
#   Completadas 45850 partidas totales
#   Completadas 45900 partidas totales
#   Completadas 45950 partidas totales
#   Completadas 46000 partidas totales
#   Completadas 46050 partidas totales
#   Completadas 46100 partidas totales
#   Completadas 46150 partidas totales
#   Completadas 46200 partidas totales
#   Completadas 46250 partidas totales
#   Completadas 46300 partidas totales
#   Completadas 46350 partidas totales
#   Completadas 46400 partidas totales
#   Completadas 46450 partidas totales
#   Completadas 46500 partidas totales
#   Completadas 46550 partidas totales
#   Completadas 46600 partidas totales
#   Completadas 46650 partidas totales
#   Completadas 46700 partidas totales
#   Completadas 46750 partidas totales
#   Completadas 46800 partidas totales
#   Completadas 46850 partidas totales
#   Completadas 46900 partidas totales
#   Completadas 46950 partidas totales
#   Completadas 47000 partidas totales
#   Completadas 47050 partidas totales
#   Completadas 47100 partidas totales
#   Completadas 47150 partidas totales
#   Completadas 47200 partidas totales
#   Completadas 47250 partidas totales
#   Completadas 47300 partidas totales
#   Completadas 47350 partidas totales
#   Completadas 47400 partidas totales
#   Completadas 47450 partidas totales
#   Completadas 47500 partidas totales
#   Completadas 47550 partidas totales
#   Completadas 47600 partidas totales
#   Completadas 47650 partidas totales
#   Completadas 47700 partidas totales
#   Completadas 47750 partidas totales
#   Completadas 47800 partidas totales
#   Completadas 47850 partidas totales
#   Completadas 47900 partidas totales
#   Completadas 47950 partidas totales
#   Completadas 48000 partidas totales
#   Completadas 48050 partidas totales
#   Completadas 48100 partidas totales
#   Completadas 48150 partidas totales
#   Completadas 48200 partidas totales
#   Completadas 48250 partidas totales
#   Completadas 48300 partidas totales
#   Completadas 48350 partidas totales
#   Completadas 48400 partidas totales
#   Completadas 48450 partidas totales
#   Completadas 48500 partidas totales
#   Completadas 48550 partidas totales
#   Completadas 48600 partidas totales
#   Completadas 48650 partidas totales
#   Completadas 48700 partidas totales
#   Completadas 48750 partidas totales
#   Completadas 48800 partidas totales
#   Completadas 48850 partidas totales
#   Completadas 48900 partidas totales
#   Completadas 48950 partidas totales
#   Completadas 49000 partidas totales
#   Completadas 49050 partidas totales
#   Completadas 49100 partidas totales
#   Completadas 49150 partidas totales
#   Completadas 49200 partidas totales
#   Completadas 49250 partidas totales
#   Completadas 49300 partidas totales
#   Completadas 49350 partidas totales
#   Completadas 49400 partidas totales
#   Completadas 49450 partidas totales
#   Completadas 49500 partidas totales
#   Completadas 49550 partidas totales
#   Completadas 49600 partidas totales
#   Completadas 49650 partidas totales
#   Completadas 49700 partidas totales
#   Completadas 49750 partidas totales
#   Completadas 49800 partidas totales
#   Completadas 49850 partidas totales
#   Completadas 49900 partidas totales
#   Completadas 49950 partidas totales
#
# Reglas vs Probabilistico (16666 partidas)...
#   Completadas 50000 partidas totales
#   Completadas 50050 partidas totales
#   Completadas 50100 partidas totales
#   Completadas 50150 partidas totales
#   Completadas 50200 partidas totales
#   Completadas 50250 partidas totales
#   Completadas 50300 partidas totales
#   Completadas 50350 partidas totales
#   Completadas 50400 partidas totales
#   Completadas 50450 partidas totales
#   Completadas 50500 partidas totales
#   Completadas 50550 partidas totales
#   Completadas 50600 partidas totales
#   Completadas 50650 partidas totales
#   Completadas 50700 partidas totales
#   Completadas 50750 partidas totales
#   Completadas 50800 partidas totales
#   Completadas 50850 partidas totales
#   Completadas 50900 partidas totales
#   Completadas 50950 partidas totales
#   Completadas 51000 partidas totales
#   Completadas 51050 partidas totales
#   Completadas 51100 partidas totales
#   Completadas 51150 partidas totales
#   Completadas 51200 partidas totales
#   Completadas 51250 partidas totales
#   Completadas 51300 partidas totales
#   Completadas 51350 partidas totales
#   Completadas 51400 partidas totales
#   Completadas 51450 partidas totales
#   Completadas 51500 partidas totales
#   Completadas 51550 partidas totales
#   Completadas 51600 partidas totales
#   Completadas 51650 partidas totales
#   Completadas 51700 partidas totales
#   Completadas 51750 partidas totales
#   Completadas 51800 partidas totales
#   Completadas 51850 partidas totales
#   Completadas 51900 partidas totales
#   Completadas 51950 partidas totales
#   Completadas 52000 partidas totales
#   Completadas 52050 partidas totales
#   Completadas 52100 partidas totales
#   Completadas 52150 partidas totales
#   Completadas 52200 partidas totales
#   Completadas 52250 partidas totales
#   Completadas 52300 partidas totales
#   Completadas 52350 partidas totales
#   Completadas 52400 partidas totales
#   Completadas 52450 partidas totales
#   Completadas 52500 partidas totales
#   Completadas 52550 partidas totales
#   Completadas 52600 partidas totales
#   Completadas 52650 partidas totales
#   Completadas 52700 partidas totales
#   Completadas 52750 partidas totales
#   Completadas 52800 partidas totales
#   Completadas 52850 partidas totales
#   Completadas 52900 partidas totales
#   Completadas 52950 partidas totales
#   Completadas 53000 partidas totales
#   Completadas 53050 partidas totales
#   Completadas 53100 partidas totales
#   Completadas 53150 partidas totales
#   Completadas 53200 partidas totales
#   Completadas 53250 partidas totales
#   Completadas 53300 partidas totales
#   Completadas 53350 partidas totales
#   Completadas 53400 partidas totales
#   Completadas 53450 partidas totales
#   Completadas 53500 partidas totales
#   Completadas 53550 partidas totales
#   Completadas 53600 partidas totales
#   Completadas 53650 partidas totales
#   Completadas 53700 partidas totales
#   Completadas 53750 partidas totales
#   Completadas 53800 partidas totales
#   Completadas 53850 partidas totales
#   Completadas 53900 partidas totales
#   Completadas 53950 partidas totales
#   Completadas 54000 partidas totales
#   Completadas 54050 partidas totales
#   Completadas 54100 partidas totales
#   Completadas 54150 partidas totales
#   Completadas 54200 partidas totales
#   Completadas 54250 partidas totales
#   Completadas 54300 partidas totales
#   Completadas 54350 partidas totales
#   Completadas 54400 partidas totales
#   Completadas 54450 partidas totales
#   Completadas 54500 partidas totales
#   Completadas 54550 partidas totales
#   Completadas 54600 partidas totales
#   Completadas 54650 partidas totales
#   Completadas 54700 partidas totales
#   Completadas 54750 partidas totales
#   Completadas 54800 partidas totales
#   Completadas 54850 partidas totales
#   Completadas 54900 partidas totales
#   Completadas 54950 partidas totales
#   Completadas 55000 partidas totales
#   Completadas 55050 partidas totales
#   Completadas 55100 partidas totales
#   Completadas 55150 partidas totales
#   Completadas 55200 partidas totales
#   Completadas 55250 partidas totales
#   Completadas 55300 partidas totales
#   Completadas 55350 partidas totales
#   Completadas 55400 partidas totales
#   Completadas 55450 partidas totales
#   Completadas 55500 partidas totales
#   Completadas 55550 partidas totales
#   Completadas 55600 partidas totales
#   Completadas 55650 partidas totales
#   Completadas 55700 partidas totales
#   Completadas 55750 partidas totales
#   Completadas 55800 partidas totales
#   Completadas 55850 partidas totales
#   Completadas 55900 partidas totales
#   Completadas 55950 partidas totales
#   Completadas 56000 partidas totales
#   Completadas 56050 partidas totales
#   Completadas 56100 partidas totales
#   Completadas 56150 partidas totales
#   Completadas 56200 partidas totales
#   Completadas 56250 partidas totales
#   Completadas 56300 partidas totales
#   Completadas 56350 partidas totales
#   Completadas 56400 partidas totales
#   Completadas 56450 partidas totales
#   Completadas 56500 partidas totales
#   Completadas 56550 partidas totales
#   Completadas 56600 partidas totales
#   Completadas 56650 partidas totales
#   Completadas 56700 partidas totales
#   Completadas 56750 partidas totales
#   Completadas 56800 partidas totales
#   Completadas 56850 partidas totales
#   Completadas 56900 partidas totales
#   Completadas 56950 partidas totales
#   Completadas 57000 partidas totales
#   Completadas 57050 partidas totales
#   Completadas 57100 partidas totales
#   Completadas 57150 partidas totales
#   Completadas 57200 partidas totales
#   Completadas 57250 partidas totales
#   Completadas 57300 partidas totales
#   Completadas 57350 partidas totales
#   Completadas 57400 partidas totales
#   Completadas 57450 partidas totales
#   Completadas 57500 partidas totales
#   Completadas 57550 partidas totales
#   Completadas 57600 partidas totales
#   Completadas 57650 partidas totales
#   Completadas 57700 partidas totales
#   Completadas 57750 partidas totales
#   Completadas 57800 partidas totales
#   Completadas 57850 partidas totales
#   Completadas 57900 partidas totales
#   Completadas 57950 partidas totales
#   Completadas 58000 partidas totales
#   Completadas 58050 partidas totales
#   Completadas 58100 partidas totales
#   Completadas 58150 partidas totales
#   Completadas 58200 partidas totales
#   Completadas 58250 partidas totales
#   Completadas 58300 partidas totales
#   Completadas 58350 partidas totales
#   Completadas 58400 partidas totales
#   Completadas 58450 partidas totales
#   Completadas 58500 partidas totales
#   Completadas 58550 partidas totales
#   Completadas 58600 partidas totales
#   Completadas 58650 partidas totales
#   Completadas 58700 partidas totales
#   Completadas 58750 partidas totales
#   Completadas 58800 partidas totales
#   Completadas 58850 partidas totales
#   Completadas 58900 partidas totales
#   Completadas 58950 partidas totales
#   Completadas 59000 partidas totales
#   Completadas 59050 partidas totales
#   Completadas 59100 partidas totales
#   Completadas 59150 partidas totales
#   Completadas 59200 partidas totales
#   Completadas 59250 partidas totales
#   Completadas 59300 partidas totales
#   Completadas 59350 partidas totales
#   Completadas 59400 partidas totales
#   Completadas 59450 partidas totales
#   Completadas 59500 partidas totales
#   Completadas 59550 partidas totales
#   Completadas 59600 partidas totales
#   Completadas 59650 partidas totales
#   Completadas 59700 partidas totales
#   Completadas 59750 partidas totales
#   Completadas 59800 partidas totales
#   Completadas 59850 partidas totales
#   Completadas 59900 partidas totales
#   Completadas 59950 partidas totales
#   Completadas 60000 partidas totales
#   Completadas 60050 partidas totales
#   Completadas 60100 partidas totales
#   Completadas 60150 partidas totales
#   Completadas 60200 partidas totales
#   Completadas 60250 partidas totales
#   Completadas 60300 partidas totales
#   Completadas 60350 partidas totales
#   Completadas 60400 partidas totales
#   Completadas 60450 partidas totales
#   Completadas 60500 partidas totales
#   Completadas 60550 partidas totales
#   Completadas 60600 partidas totales
#   Completadas 60650 partidas totales
#   Completadas 60700 partidas totales
#   Completadas 60750 partidas totales
#   Completadas 60800 partidas totales
#   Completadas 60850 partidas totales
#   Completadas 60900 partidas totales
#   Completadas 60950 partidas totales
#   Completadas 61000 partidas totales
#   Completadas 61050 partidas totales
#   Completadas 61100 partidas totales
#   Completadas 61150 partidas totales
#   Completadas 61200 partidas totales
#   Completadas 61250 partidas totales
#   Completadas 61300 partidas totales
#   Completadas 61350 partidas totales
#   Completadas 61400 partidas totales
#   Completadas 61450 partidas totales
#   Completadas 61500 partidas totales
#   Completadas 61550 partidas totales
#   Completadas 61600 partidas totales
#   Completadas 61650 partidas totales
#   Completadas 61700 partidas totales
#   Completadas 61750 partidas totales
#   Completadas 61800 partidas totales
#   Completadas 61850 partidas totales
#   Completadas 61900 partidas totales
#   Completadas 61950 partidas totales
#   Completadas 62000 partidas totales
#   Completadas 62050 partidas totales
#   Completadas 62100 partidas totales
#   Completadas 62150 partidas totales
#   Completadas 62200 partidas totales
#   Completadas 62250 partidas totales
#   Completadas 62300 partidas totales
#   Completadas 62350 partidas totales
#   Completadas 62400 partidas totales
#   Completadas 62450 partidas totales
#   Completadas 62500 partidas totales
#   Completadas 62550 partidas totales
#   Completadas 62600 partidas totales
#   Completadas 62650 partidas totales
#   Completadas 62700 partidas totales
#   Completadas 62750 partidas totales
#   Completadas 62800 partidas totales
#   Completadas 62850 partidas totales
#   Completadas 62900 partidas totales
#   Completadas 62950 partidas totales
#   Completadas 63000 partidas totales
#   Completadas 63050 partidas totales
#   Completadas 63100 partidas totales
#   Completadas 63150 partidas totales
#   Completadas 63200 partidas totales
#   Completadas 63250 partidas totales
#   Completadas 63300 partidas totales
#   Completadas 63350 partidas totales
#   Completadas 63400 partidas totales
#   Completadas 63450 partidas totales
#   Completadas 63500 partidas totales
#   Completadas 63550 partidas totales
#   Completadas 63600 partidas totales
#   Completadas 63650 partidas totales
#   Completadas 63700 partidas totales
#   Completadas 63750 partidas totales
#   Completadas 63800 partidas totales
#   Completadas 63850 partidas totales
#   Completadas 63900 partidas totales
#   Completadas 63950 partidas totales
#   Completadas 64000 partidas totales
#   Completadas 64050 partidas totales
#   Completadas 64100 partidas totales
#   Completadas 64150 partidas totales
#   Completadas 64200 partidas totales
#   Completadas 64250 partidas totales
#   Completadas 64300 partidas totales
#   Completadas 64350 partidas totales
#   Completadas 64400 partidas totales
#   Completadas 64450 partidas totales
#   Completadas 64500 partidas totales
#   Completadas 64550 partidas totales
#   Completadas 64600 partidas totales
#   Completadas 64650 partidas totales
#   Completadas 64700 partidas totales
# ...
#   Completadas 80400 partidas totales
#   Completadas 80450 partidas totales
#   Completadas 80500 partidas totales
#   Completadas 80550 partidas totales
#   Completadas 80600 partidas totales
#   Completadas 80650 partidas totales
#   Completadas 80700 partidas totales
#   Completadas 80750 partidas totales
#   Completadas 80800 partidas totales
#   Completadas 80850 partidas totales
#   Completadas 80900 partidas totales
#   Completadas 80950 partidas totales
#   Completadas 81000 partidas totales
#   Completadas 81050 partidas totales
#   Completadas 81100 partidas totales
#   Completadas 81150 partidas totales
#   Completadas 81200 partidas totales
#   Completadas 81250 partidas totales
#   Completadas 81300 partidas totales
#   Completadas 81350 partidas totales
#   Completadas 81400 partidas totales
#   Completadas 81450 partidas totales
#   Completadas 81500 partidas totales
#   Completadas 81550 partidas totales
#   Completadas 81600 partidas totales
#   Completadas 81650 partidas totales
#   Completadas 81700 partidas totales
#   Completadas 81750 partidas totales
#   Completadas 81800 partidas totales
#   Completadas 81850 partidas totales
#   Completadas 81900 partidas totales
#   Completadas 81950 partidas totales
#   Completadas 82000 partidas totales
#   Completadas 82050 partidas totales
#   Completadas 82100 partidas totales
#   Completadas 82150 partidas totales
#   Completadas 82200 partidas totales
#   Completadas 82250 partidas totales
#   Completadas 82300 partidas totales
#   Completadas 82350 partidas totales
#   Completadas 82400 partidas totales
#   Completadas 82450 partidas totales
#   Completadas 82500 partidas totales
#   Completadas 82550 partidas totales
#   Completadas 82600 partidas totales
#   Completadas 82650 partidas totales
#   Completadas 82700 partidas totales
#   Completadas 82750 partidas totales
#   Completadas 82800 partidas totales
#   Completadas 82850 partidas totales
#   Completadas 82900 partidas totales
#   Completadas 82950 partidas totales
#   Completadas 83000 partidas totales
#   Completadas 83050 partidas totales
#   Completadas 83100 partidas totales
#   Completadas 83150 partidas totales
#   Completadas 83200 partidas totales
#   Completadas 83250 partidas totales
#   Completadas 83300 partidas totales
#
# Probabilistico vs CFR (16666 partidas)...
#   Completadas 83350 partidas totales
#   Completadas 83400 partidas totales
#   Completadas 83450 partidas totales
#   Completadas 83500 partidas totales
#   Completadas 83550 partidas totales
#   Completadas 83600 partidas totales
#   Completadas 83650 partidas totales
#   Completadas 83700 partidas totales
#   Completadas 83750 partidas totales
#   Completadas 83800 partidas totales
#   Completadas 83850 partidas totales
#   Completadas 83900 partidas totales
#   Completadas 83950 partidas totales
#   Completadas 84000 partidas totales
#   Completadas 84050 partidas totales
#   Completadas 84100 partidas totales
#   Completadas 84150 partidas totales
#   Completadas 84200 partidas totales
#   Completadas 84250 partidas totales
#   Completadas 84300 partidas totales
#   Completadas 84350 partidas totales
#   Completadas 84400 partidas totales
#   Completadas 84450 partidas totales
#   Completadas 84500 partidas totales
#   Completadas 84550 partidas totales
#   Completadas 84600 partidas totales
#   Completadas 84650 partidas totales
#   Completadas 84700 partidas totales
#   Completadas 84750 partidas totales
#   Completadas 84800 partidas totales
#   Completadas 84850 partidas totales
#   Completadas 84900 partidas totales
#   Completadas 84950 partidas totales
#   Completadas 85000 partidas totales
#   Completadas 85050 partidas totales
#   Completadas 85100 partidas totales
#   Completadas 85150 partidas totales
#   Completadas 85200 partidas totales
#   Completadas 85250 partidas totales
#   Completadas 85300 partidas totales
#   Completadas 85350 partidas totales
#   Completadas 85400 partidas totales
#   Completadas 85450 partidas totales
#   Completadas 85500 partidas totales
#   Completadas 85550 partidas totales
#   Completadas 85600 partidas totales
#   Completadas 85650 partidas totales
#   Completadas 85700 partidas totales
#   Completadas 85750 partidas totales
#   Completadas 85800 partidas totales
#   Completadas 85850 partidas totales
#   Completadas 85900 partidas totales
#   Completadas 85950 partidas totales
#   Completadas 86000 partidas totales
#   Completadas 86050 partidas totales
#   Completadas 86100 partidas totales
#   Completadas 86150 partidas totales
#   Completadas 86200 partidas totales
#   Completadas 86250 partidas totales
#   Completadas 86300 partidas totales
#   Completadas 86350 partidas totales
#   Completadas 86400 partidas totales
#   Completadas 86450 partidas totales
#   Completadas 86500 partidas totales
#   Completadas 86550 partidas totales
#   Completadas 86600 partidas totales
#   Completadas 86650 partidas totales
#   Completadas 86700 partidas totales
#   Completadas 86750 partidas totales
#   Completadas 86800 partidas totales
#   Completadas 86850 partidas totales
#   Completadas 86900 partidas totales
#   Completadas 86950 partidas totales
#   Completadas 87000 partidas totales
#   Completadas 87050 partidas totales
#   Completadas 87100 partidas totales
#   Completadas 87150 partidas totales
#   Completadas 87200 partidas totales
#   Completadas 87250 partidas totales
#   Completadas 87300 partidas totales
#   Completadas 87350 partidas totales
#   Completadas 87400 partidas totales
#   Completadas 87450 partidas totales
#   Completadas 87500 partidas totales
#   Completadas 87550 partidas totales
#   Completadas 87600 partidas totales
#   Completadas 87650 partidas totales
#   Completadas 87700 partidas totales
#   Completadas 87750 partidas totales
#   Completadas 87800 partidas totales
#   Completadas 87850 partidas totales
#   Completadas 87900 partidas totales
#   Completadas 87950 partidas totales
#   Completadas 88000 partidas totales
#   Completadas 88050 partidas totales
#   Completadas 88100 partidas totales
#   Completadas 88150 partidas totales
#   Completadas 88200 partidas totales
#   Completadas 88250 partidas totales
#   Completadas 88300 partidas totales
#   Completadas 88350 partidas totales
#   Completadas 88400 partidas totales
#   Completadas 88450 partidas totales
#   Completadas 88500 partidas totales
#   Completadas 88550 partidas totales
#   Completadas 88600 partidas totales
#   Completadas 88650 partidas totales
#   Completadas 88700 partidas totales
#   Completadas 88750 partidas totales
#   Completadas 88800 partidas totales
#   Completadas 88850 partidas totales
#   Completadas 88900 partidas totales
#   Completadas 88950 partidas totales
#   Completadas 89000 partidas totales
#   Completadas 89050 partidas totales
#   Completadas 89100 partidas totales
#   Completadas 89150 partidas totales
#   Completadas 89200 partidas totales
#   Completadas 89250 partidas totales
#   Completadas 89300 partidas totales
#   Completadas 89350 partidas totales
#   Completadas 89400 partidas totales
#   Completadas 89450 partidas totales
#   Completadas 89500 partidas totales
#   Completadas 89550 partidas totales
#   Completadas 89600 partidas totales
#   Completadas 89650 partidas totales
#   Completadas 89700 partidas totales
#   Completadas 89750 partidas totales
#   Completadas 89800 partidas totales
#   Completadas 89850 partidas totales
#   Completadas 89900 partidas totales
#   Completadas 89950 partidas totales
#   Completadas 90000 partidas totales
#   Completadas 90050 partidas totales
#   Completadas 90100 partidas totales
#   Completadas 90150 partidas totales
#   Completadas 90200 partidas totales
#   Completadas 90250 partidas totales
#   Completadas 90300 partidas totales
#   Completadas 90350 partidas totales
#   Completadas 90400 partidas totales
#   Completadas 90450 partidas totales
#   Completadas 90500 partidas totales
#   Completadas 90550 partidas totales
#   Completadas 90600 partidas totales
#   Completadas 90650 partidas totales
#   Completadas 90700 partidas totales
#   Completadas 90750 partidas totales
#   Completadas 90800 partidas totales
#   Completadas 90850 partidas totales
#   Completadas 90900 partidas totales
#   Completadas 90950 partidas totales
#   Completadas 91000 partidas totales
#   Completadas 91050 partidas totales
#   Completadas 91100 partidas totales
#   Completadas 91150 partidas totales
#   Completadas 91200 partidas totales
#   Completadas 91250 partidas totales
#   Completadas 91300 partidas totales
#   Completadas 91350 partidas totales
#   Completadas 91400 partidas totales
#   Completadas 91450 partidas totales
#   Completadas 91500 partidas totales
#   Completadas 91550 partidas totales
#   Completadas 91600 partidas totales
#   Completadas 91650 partidas totales
#   Completadas 91700 partidas totales
#   Completadas 91750 partidas totales
#   Completadas 91800 partidas totales
#   Completadas 91850 partidas totales
#   Completadas 91900 partidas totales
#   Completadas 91950 partidas totales
#   Completadas 92000 partidas totales
#   Completadas 92050 partidas totales
#   Completadas 92100 partidas totales
#   Completadas 92150 partidas totales
#   Completadas 92200 partidas totales
#   Completadas 92250 partidas totales
#   Completadas 92300 partidas totales
#   Completadas 92350 partidas totales
#   Completadas 92400 partidas totales
#   Completadas 92450 partidas totales
#   Completadas 92500 partidas totales
#   Completadas 92550 partidas totales
#   Completadas 92600 partidas totales
#   Completadas 92650 partidas totales
#   Completadas 92700 partidas totales
#   Completadas 92750 partidas totales
#   Completadas 92800 partidas totales
#   Completadas 92850 partidas totales
#   Completadas 92900 partidas totales
#   Completadas 92950 partidas totales
#   Completadas 93000 partidas totales
#   Completadas 93050 partidas totales
#   Completadas 93100 partidas totales
#   Completadas 93150 partidas totales
#   Completadas 93200 partidas totales
#   Completadas 93250 partidas totales
#   Completadas 93300 partidas totales
#   Completadas 93350 partidas totales
#   Completadas 93400 partidas totales
#   Completadas 93450 partidas totales
#   Completadas 93500 partidas totales
#   Completadas 93550 partidas totales
#   Completadas 93600 partidas totales
#   Completadas 93650 partidas totales
#   Completadas 93700 partidas totales
#   Completadas 93750 partidas totales
#   Completadas 93800 partidas totales
#   Completadas 93850 partidas totales
#   Completadas 93900 partidas totales
#   Completadas 93950 partidas totales
#   Completadas 94000 partidas totales
#   Completadas 94050 partidas totales
#   Completadas 94100 partidas totales
#   Completadas 94150 partidas totales
#   Completadas 94200 partidas totales
#   Completadas 94250 partidas totales
#   Completadas 94300 partidas totales
#   Completadas 94350 partidas totales
#   Completadas 94400 partidas totales
#   Completadas 94450 partidas totales
#   Completadas 94500 partidas totales
#   Completadas 94550 partidas totales
#   Completadas 94600 partidas totales
#   Completadas 94650 partidas totales
#   Completadas 94700 partidas totales
#   Completadas 94750 partidas totales
#   Completadas 94800 partidas totales
#   Completadas 94850 partidas totales
#   Completadas 94900 partidas totales
#   Completadas 94950 partidas totales
#   Completadas 95000 partidas totales
#   Completadas 95050 partidas totales
#   Completadas 95100 partidas totales
#   Completadas 95150 partidas totales
#   Completadas 95200 partidas totales
#   Completadas 95250 partidas totales
#   Completadas 95300 partidas totales
#   Completadas 95350 partidas totales
#   Completadas 95400 partidas totales
#   Completadas 95450 partidas totales
#   Completadas 95500 partidas totales
#   Completadas 95550 partidas totales
#   Completadas 95600 partidas totales
#   Completadas 95650 partidas totales
#   Completadas 95700 partidas totales
#   Completadas 95750 partidas totales
#   Completadas 95800 partidas totales
#   Completadas 95850 partidas totales
#   Completadas 95900 partidas totales
#   Completadas 95950 partidas totales
#   Completadas 96000 partidas totales
#   Completadas 96050 partidas totales
#   Completadas 96100 partidas totales
#   Completadas 96150 partidas totales
#   Completadas 96200 partidas totales
#   Completadas 96250 partidas totales
#   Completadas 96300 partidas totales
#   Completadas 96350 partidas totales
#   Completadas 96400 partidas totales
#   Completadas 96450 partidas totales
#   Completadas 96500 partidas totales
#   Completadas 96550 partidas totales
#   Completadas 96600 partidas totales
#   Completadas 96650 partidas totales
#   Completadas 96700 partidas totales
#   Completadas 96750 partidas totales
#   Completadas 96800 partidas totales
#   Completadas 96850 partidas totales
#   Completadas 96900 partidas totales
#   Completadas 96950 partidas totales
#   Completadas 97000 partidas totales
#   Completadas 97050 partidas totales
#   Completadas 97100 partidas totales
#   Completadas 97150 partidas totales
#   Completadas 97200 partidas totales
#   Completadas 97250 partidas totales
#   Completadas 97300 partidas totales
#   Completadas 97350 partidas totales
#   Completadas 97400 partidas totales
#   Completadas 97450 partidas totales
#   Completadas 97500 partidas totales
#   Completadas 97550 partidas totales
#   Completadas 97600 partidas totales
#   Completadas 97650 partidas totales
#   Completadas 97700 partidas totales
#   Completadas 97750 partidas totales
#   Completadas 97800 partidas totales
#   Completadas 97850 partidas totales
#   Completadas 97900 partidas totales
#   Completadas 97950 partidas totales
#   Completadas 98000 partidas totales
#   Completadas 98050 partidas totales
#   Completadas 98100 partidas totales
#   Completadas 98150 partidas totales
#   Completadas 98200 partidas totales
#   Completadas 98250 partidas totales
#   Completadas 98300 partidas totales
#   Completadas 98350 partidas totales
#   Completadas 98400 partidas totales
#   Completadas 98450 partidas totales
#   Completadas 98500 partidas totales
#   Completadas 98550 partidas totales
#   Completadas 98600 partidas totales
#   Completadas 98650 partidas totales
#   Completadas 98700 partidas totales
#   Completadas 98750 partidas totales
#   Completadas 98800 partidas totales
#   Completadas 98850 partidas totales
#   Completadas 98900 partidas totales
#   Completadas 98950 partidas totales
#   Completadas 99000 partidas totales
#   Completadas 99050 partidas totales
#   Completadas 99100 partidas totales
#   Completadas 99150 partidas totales
#   Completadas 99200 partidas totales
#   Completadas 99250 partidas totales
#   Completadas 99300 partidas totales
#   Completadas 99350 partidas totales
#   Completadas 99400 partidas totales
#   Completadas 99450 partidas totales
#   Completadas 99500 partidas totales
#   Completadas 99550 partidas totales
#   Completadas 99600 partidas totales
#   Completadas 99650 partidas totales
#   Completadas 99700 partidas totales
#   Completadas 99750 partidas totales
#   Completadas 99800 partidas totales
#   Completadas 99850 partidas totales
#   Completadas 99900 partidas totales
#   Completadas 99950 partidas totales
#
# ============================================================
# RESUMEN DE RESULTADOS
# ============================================================
#         Agente  Tasa_Victoria_%  Partidas_Jugadas  Victorias  Derrotas  Tiempo_Promedio_Jugada_ms  Turnos_Promedio_Por_Juego  Desv_Est_Tiempo_ms
#         Random        50.426017             49998      25212     24786                   0.035615                  94.707708            0.032996
#         Reglas        50.112004             49998      25055     24943                   0.036913                  94.741870            0.033282
# Probabilistico        49.835993             49998      24917     25081                   0.040075                  94.695788            0.034732
#            CFR        49.625985             49998      24812     25186                   0.045197                  94.380095            0.031693
#
# ✓ Archivos guardados:
#   - uno_agents_summary.csv (resumen por agente)
#   - uno_agents_detailed.csv (datos de cada partida)
#
# ============================================================
# ANÁLISIS COMPARATIVO
# ============================================================
#
# Random:
#   Victorias: 25212/49998
#   Tasa victoria: 50.43%
#   Tiempo: 0.036 ms
#
# Reglas:
#   Victorias: 25055/49998
#   Tasa victoria: 50.11%
#   Tiempo: 0.037 ms
#
# Probabilistico:
#   Victorias: 24917/49998
#   Tasa victoria: 49.84%
#   Tiempo: 0.040 ms
#
# CFR:
#   Victorias: 24812/49998
#   Tasa victoria: 49.63%
#   Tiempo: 0.045 ms
